# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense,Flatten,Dropout
from keras.datasets import fashion_mnist
from keras.models import Sequential

# %%
(X_train,y_train),(X_test,y_test) = fashion_mnist.load_data()

# %%
y_train
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
X_train = X_train/255
X_test = X_test/255

# %%
model = Sequential([
    Flatten(),
    Dense(100,activation = 'relu'),
    # Dropout(0.3),
    Dense(10,activation = 'softmax')
])

# %%
model.compile(optimizer='adam' , loss = 'sparse_categorical_crossentropy' ,metrics=['accuracy'] )

# %%
model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2359 - accuracy: 0.9126
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2304 - accuracy: 0.9138
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2219 - accuracy: 0.9172
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2172 - accuracy: 0.9200
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2102 - accuracy: 0.9214

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3556 - accuracy: 0.8790
# [0.35564133524894714, 0.8790000081062317]

# %%
from sklearn.metrics import classification_report

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 313/313 [==============================] - 1s 1ms/step
# array([[8.2992391e-11, 4.1515370e-13, 2.3880652e-12, ..., 9.7104232e-04,
#         2.0158067e-08, 9.9900335e-01],
#        [2.1649368e-05, 6.1486234e-17, 9.9949133e-01, ..., 9.4497662e-21,
#         1.0205957e-11, 2.3733935e-16],
#        [7.0255672e-12, 1.0000000e+00, 4.6673353e-15, ..., 2.0198105e-21,
#         6.3378785e-19, 4.7043342e-16],
#        ...,
#        [2.0975119e-06, 8.3081693e-12, 1.4112453e-06, ..., 1.1977395e-11,
#         9.9994159e-01, 1.5725687e-14],
#        [4.9253268e-10, 9.9999714e-01, 1.9053831e-11, ..., 1.1588354e-16,
#         2.3519251e-13, 1.5745095e-12],
#        [1.2484475e-06, 1.5444358e-12, 1.8598733e-07, ..., 8.9044906e-06,
#         8.6629647e-05, 6.9575258e-08]], dtype=float32)

# %%
import numpy as np

# %%
y_pred_label = [np.argmax(i) for i in y_pred]
y_pred_label
# Out:
# [9,
#  2,
#  1,
#  1,
#  6,
#  1,
#  4,
#  6,
#  5,
#  7,
#  4,
#  5,
#  8,
#  3,
#  4,
#  1,
#  2,
#  2,
#  8,
#  0,
#  2,
#  5,
#  7,
#  9,
#  1,
#  2,
#  6,
#  0,
#  9,
#  3,
#  8,
#  8,
#  3,
#  3,
#  8,
#  0,
#  7,
#  5,
#  7,
#  9,
#  6,
#  1,
#  6,
#  9,
#  6,
#  7,
#  2,
#  1,
#  2,
#  6,
#  4,
#  2,
#  5,
#  8,
#  2,
#  2,
#  8,
#  4,
#  8,
#  0,
#  7,
#  7,
#  8,
#  5,
#  1,
#  1,
#  2,
#  4,
#  7,
#  8,
#  7,
#  0,
#  2,
#  6,
#  2,
#  3,
#  1,
#  2,
#  8,
#  4,
#  1,
#  8,
#  5,
#  9,
#  5,
#  0,
#  3,
#  2,
#  0,
#  2,
#  5,
#  3,
#  6,
#  7,
#  1,
#  8,
#  0,
#  1,
#  4,
#  2,
#  3,
#  6,
#  7,
#  6,
#  7,
#  8,
#  5,
#  9,
#  9,
#  4,
#  2,
#  5,
#  7,
#  0,
#  5,
#  2,
#  8,
#  4,
#  7,
#  8,
#  0,
#  0,
#  9,
#  9,
#  3,
#  0,
#  8,
#  2,
#  1,
#  5,
#  4,
#  1,
#  9,
#  1,
#  8,
#  4,
#  6,
#  1,
#  2,
#  5,
#  1,
#  6,
#  0,
#  0,
#  1,
#  6,
#  1,
#  3,
#  2,
#  2,
#  3,
#  2,
#  1,
#  3,
#  5,
#  2,
#  4,
#  7,
#  9,
#  3,
#  7,
#  2,
#  3,
#  9,
#  0,
#  9,
#  4,
#  7,
#  4,
#  2,
#  0,
#  5,
#  6,
#  1,
#  2,
#  1,
#  3,
#  0,
#  9,
#  1,
#  0,
#  9,
#  3,
#  6,
#  7,
#  9,
#  9,
#  4,
#  4,
#  7,
#  1,
#  2,
#  3,
#  6,
#  3,
#  2,
#  8,
#  3,
#  6,
#  1,
#  1,
#  0,
#  2,
#  9,
#  2,
#  4,
#  0,
#  7,
#  9,
#  8,
#  4,
#  1,
#  8,
#  4,
#  1,
#  3,
#  1,
#  6,
#  7,
#  2,
#  8,
#  5,
#  4,
#  0,
#  7,
#  7,
#  6,
#  6,
#  7,
#  6,
#  7,
#  8,
#  9,
#  2,
#  9,
#  0,
#  5,
#  1,
#  4,
#  2,
#  5,
#  6,
#  9,
#  2,
#  2,
#  8,
#  6,
#  4,
#  2,
#  2,
#  9,
#  7,
#  6,
#  5,
#  5,
#  2,
#  8,
#  5,
#  2,
#  3,
#  0,
#  4,
#  8,
#  6,
#  0,
#  6,
#  3,
#  8,
#  9,
#  6,
#  1,
#  6,
#  0,
#  2,
#  3,
#  0,
#  8,
#  3,
#  7,
#  4,
#  0,
#  1,
#  2,
#  4,
#  0,
#  6,
#  6,
#  7,
#  5,
#  4,
#  5,
#  9,
#  5,
#  6,
#  5,
#  5,
#  1,
#  9,
#  8,
#  8,
#  3,
#  3,
#  6,
#  8,
#  6,
#  0,
#  2,
#  9,
#  7,
#  7,
#  1,
#  3,
#  6,
#  4,
#  6,
#  4,
#  7,
#  1,
#  6,
#  4,
#  2,
#  2,
#  6,
#  5,
#  6,
#  2,
#  7,
#  7,
#  7,
#  3,
#  3,
#  9,
#  6,
#  7,
#  1,
#  3,
#  7,
#  2,
#  2,
#  3,
#  4,
#  0,
#  3,
#  1,
#  6,
#  1,
#  9,
#  4,
#  9,
#  9,
#  1,
#  7,
#  8,
#  3,
#  6,
#  6,
#  2,
#  4,
#  8,
#  6,
#  1,
#  6,
#  2,
#  4,
#  4,
#  7,
#  3,
#  2,
#  6,
#  5,
#  0,
#  7,
#  9,
#  4,
#  6,
#  9,
#  3,
#  9,
#  3,
#  2,
#  5,
#  6,
#  0,
#  3,
#  5,
#  8,
#  1,
#  6,
#  2,
#  6,
#  6,
#  4,
#  9,
#  5,
#  2,
#  6,
#  6,
#  6,
#  1,
#  2,
#  0,
#  9,
#  7,
#  0,
#  4,
#  4,
#  6,
#  6,
#  2,
#  1,
#  6,
#  6,
#  7,
#  6,
#  9,
#  4,
#  2,
#  1,
#  5,
#  4,
#  5,
#  3,
#  8,
#  5,
#  8,
#  4,
#  4,
#  8,
#  9,
#  8,
#  6,
#  2,
#  4,
#  4,
#  2,
#  4,
#  1,
#  6,
#  1,
#  3,
#  0,
#  7,
#  8,
#  8,
#  4,
#  5,
#  3,
#  1,
#  9,
#  5,
#  3,
#  3,
#  0,
#  1,
#  2,
#  2,
#  9,
#  2,
#  0,
#  6,
#  0,
#  4,
#  2,
#  0,
#  0,
#  3,
#  3,
#  8,
#  2,
#  8,
#  9,
#  4,
#  0,
#  7,
#  6,
#  4,
#  6,
#  9,
#  2,
#  9,
#  5,
#  9,
#  3,
#  7,
#  5,
#  7,
#  8,
#  1,
#  0,
#  0,
#  6,
#  4,
#  8,
#  9,
#  7,
#  9,
#  1,
#  2,
#  7,
#  0,
#  6,
#  0,
#  5,
#  7,
#  1,
#  8,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  6,
#  1,
#  9,
#  8,
#  5,
#  1,
#  9,
#  1,
#  2,
#  8,
#  3,
#  8,
#  9,
#  2,
#  2,
#  4,
#  8,
#  0,
#  2,
#  0,
#  5,
#  8,
#  8,
#  5,
#  3,
#  9,
#  4,
#  3,
#  4,
#  4,
#  5,
#  1,
#  0,
#  1,
#  2,
#  6,
#  4,
#  9,
#  6,
#  1,
#  5,
#  1,
#  1,
#  1,
#  9,
#  3,
#  4,
#  5,
#  3,
#  6,
#  2,
#  6,
#  4,
#  6,
#  0,
#  5,
#  8,
#  2,
#  3,
#  4,
#  6,
#  7,
#  7,
#  8,
#  9,
#  3,
#  3,
#  8,
#  7,
#  6,
#  7,
#  9,
#  3,
#  4,
#  6,
#  3,
#  5,
#  8,
#  1,
#  1,
#  5,
#  9,
#  4,
#  6,
#  5,
#  7,
#  8,
#  1,
#  2,
#  9,
#  7,
#  7,
#  1,
#  0,
#  9,
#  3,
#  2,
#  9,
#  6,
#  7,
#  6,
#  8,
#  2,
#  7,
#  0,
#  2,
#  3,
#  8,
#  2,
#  2,
#  6,
#  9,
#  3,
#  0,
#  7,
#  8,
#  6,
#  2,
#  9,
#  4,
#  2,
#  6,
#  6,
#  2,
#  0,
#  4,
#  4,
#  2,
#  7,
#  5,
#  8,
#  4,
#  9,
#  1,
#  0,
#  5,
#  4,
#  4,
#  4,
#  6,
#  0,
#  4,
#  5,
#  6,
#  0,
#  4,
#  5,
#  4,
#  1,
#  3,
#  1,
#  3,
#  2,
#  4,
#  3,
#  8,
#  2,
#  8,
#  6,
#  5,
#  0,
#  4,
#  0,
#  8,
#  5,
#  0,
#  8,
#  2,
#  9,
#  6,
#  8,
#  9,
#  6,
#  4,
#  2,
#  9,
#  6,
#  2,
#  5,
#  0,
#  9,
#  5,
#  3,
#  6,
#  6,
#  8,
#  3,
#  3,
#  8,
#  1,
#  4,
#  0,
#  9,
#  7,
#  9,
#  4,
#  8,
#  9,
#  1,
#  0,
#  7,
#  3,
#  0,
#  2,
#  6,
#  7,
#  1,
#  6,
#  0,
#  8,
#  7,
#  2,
#  6,
#  4,
#  6,
#  4,
#  1,
#  5,
#  9,
#  0,
#  0,
#  1,
#  6,
#  5,
#  0,
#  0,
#  3,
#  3,
#  3,
#  8,
#  1,
#  1,
#  8,
#  5,
#  7,
#  7,
#  8,
#  7,
#  2,
#  0,
#  7,
#  6,
#  8,
#  0,
#  9,
#  7,
#  6,
#  1,
#  6,
#  2,
#  4,
#  8,
#  2,
#  6,
#  3,
#  6,
#  8,
#  4,
#  0,
#  8,
#  9,
#  2,
#  4,
#  5,
#  9,
#  1,
#  4,
#  4,
#  9,
#  2,
#  1,
#  7,
#  9,
#  5,
#  8,
#  3,
#  7,
#  7,
#  1,
#  1,
#  1,
#  6,
#  9,
#  5,
#  3,
#  8,
#  4,
#  2,
#  9,
#  2,
#  8,
#  3,
#  2,
#  4,
#  4,
#  7,
#  1,
#  4,
#  9,
#  3,
#  5,
#  8,
#  5,
#  4,
#  7,
#  2,
#  8,
#  5,
#  9,
#  3,
#  3,
#  6,
#  7,
#  1,
#  7,
#  3,
#  5,
#  4,
#  4,
#  5,
#  8,
#  3,
#  7,
#  1,
#  2,
#  6,
#  1,
#  9,
#  8,
#  2,
#  7,
#  1,
#  3,
#  7,
#  5,
#  9,
#  9,
#  1,
#  8,
#  4,
#  5,
#  7,
#  1,
#  9,
#  8,
#  1,
#  0,
#  0,
#  2,
#  1,
#  7,
#  1,
#  1,
#  5,
#  7,
#  1,
#  5,
#  2,
#  2,
#  3,
#  3,
#  1,
#  1,
#  4,
#  9,
#  4,
#  3,
#  7,
#  7,
#  6,
#  8,
#  9,
#  9,
#  6,
#  1,
#  3,
#  4,
#  0,
#  0,
#  5,
#  9,
#  2,
#  0,
#  5,
#  5,
#  1,
#  5,
#  7,
#  8,
#  7,
#  7,
#  3,
#  6,
#  6,
#  0,
#  4,
#  6,
#  6,
#  0,
#  2,
#  5,
#  5,
#  1,
#  2,
#  0,
#  9,
#  3,
#  7,
#  8,
#  4,
#  8,
#  3,
#  4,
#  7,
#  6,
#  7,
#  4,
#  8,
#  6,
#  3,
#  4,
#  4,
#  3,
#  6,
#  9,
#  6,
#  6,
#  4,
#  9,
#  1,
#  8,
#  1,
#  7,
#  5,
#  5,
#  6,
#  6,
#  2,
#  1,
#  6,
#  5,
#  4,
#  0,
#  0,
#  6,
#  7,
#  5,
#  0,
#  4,
#  5,
#  9,
#  6,
#  8,
#  2,
#  6,
#  4,
#  6,
#  2,
#  9,
#  6,
#  7,
#  7,
#  1,
#  4,
#  4,
#  6,
#  5,
#  0,
#  9,
#  9,
#  8,
#  8,
#  3,
#  6,
#  2,
#  4,
#  6,
#  6,
#  3,
#  2,
#  3,
#  5,
#  2,
#  9,
#  3,
#  4,
#  7,
#  7,
#  ...]

# %%
print(classification_report(y_test,y_pred_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.71      0.79      1000
#            1       0.99      0.97      0.98      1000
#            2       0.80      0.80      0.80      1000
#            3       0.90      0.87      0.88      1000
#            4       0.77      0.84      0.81      1000
#            5       0.98      0.95      0.97      1000
#            6       0.65      0.75      0.70      1000
#            7       0.95      0.95      0.95      1000
#            8       0.97      0.97      0.97      1000
#            9       0.94      0.97      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
class_labels = ["T-shirt/top","Trouser","Pullover","Dress","Coat","Sandal","Shirt","Sneaker","Bag","Ankle boot"]

# %%
class_labels[np.argmax(y_pred[10])]
# Out:
# 'Coat'
